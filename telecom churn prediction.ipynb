# %%
import pandas as pd

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.replace([' ','0.0'],inplace=True)
# Out:
# /tmp/ipykernel_70993/1484463632.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df.TotalCharges.replace([' ','0.0'],inplace=True)
# /tmp/ipykernel_70993/1484463632.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.TotalCharges.replace([' ','0.0'],inplace=True)

# %%
df.TotalCharges=df['TotalCharges'].astype(float)

# %% [markdown]
# for i in df:
#   print(i,df[i].unique())

# %%
for i in df:
  print(i,df[i].unique())
# Out:
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['No' 'Yes']
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService ['No' 'Yes']
# MultipleLines ['No phone service' 'No' 'Yes']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['No' 'Yes' 'No internet service']
# StreamingTV ['No' 'Yes' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']
# Contract ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ['Yes' 'No']
# PaymentMethod ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn ['No' 'Yes']

# %%
d1=df

# %%
d1.PaperlessBilling.replace({'Yes':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/2531123738.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.PaperlessBilling.replace({'Yes':1},inplace=True)

# %%
d1.PhoneService.replace({'Yes':1,'No':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/2611798066.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.PhoneService.replace({'Yes':1,'No':0},inplace=True)
# /tmp/ipykernel_70993/2611798066.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.PhoneService.replace({'Yes':1,'No':0},inplace=True)

# %%
d1=pd.get_dummies(df,columns=['PaymentMethod','Contract'])

# %%
d1.Churn.replace({'Yes':0,'No':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/381140565.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.Churn.replace({'Yes':0,'No':1},inplace=True)
# /tmp/ipykernel_70993/381140565.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.Churn.replace({'Yes':0,'No':1},inplace=True)

# %%
d1=pd.get_dummies(d1,columns=['InternetService'])

# %%
d1.gender.replace({'Female':0,'Male':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/2552455300.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.gender.replace({'Female':0,'Male':1},inplace=True)
# /tmp/ipykernel_70993/2552455300.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.gender.replace({'Female':0,'Male':1},inplace=True)

# %%
d1.Partner=d1.Partner.map({'Yes':1,'No':0})

# %%
(d1.dtypes==object)
# Out:
# gender                                     False
# SeniorCitizen                              False
# Partner                                    False
# Dependents                                  True
# tenure                                     False
# PhoneService                               False
# MultipleLines                               True
# OnlineSecurity                              True
# OnlineBackup                                True
# DeviceProtection                            True
# TechSupport                                 True
# StreamingTV                                 True
# StreamingMovies                             True
# PaperlessBilling                            True
# MonthlyCharges                             False
# TotalCharges                               False
# Churn                                      False
# PaymentMethod_Bank transfer (automatic)    False
# PaymentMethod_Credit card (automatic)      False
# PaymentMethod_Electronic check             False
# PaymentMethod_Mailed check                 False
# Contract_Month-to-month                    False
# Contract_One year                          False
# Contract_Two year                          False
# InternetService_DSL                        False
# InternetService_Fiber optic                False
# InternetService_No                         False
# dtype: bool

# %%
for i in d1:
  print(i,d1[i].unique())
# Out:
# gender [0 1]
# SeniorCitizen [0 1]
# Partner [1 0]
# Dependents ['No' 'Yes']
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService [0 1]
# MultipleLines ['No phone service' 'No' 'Yes']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['No' 'Yes' 'No internet service']
# StreamingTV ['No' 'Yes' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']
# PaperlessBilling [1 'No']
# MonthlyCharges [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn [1 0]
# PaymentMethod_Bank transfer (automatic) [False  True]
# PaymentMethod_Credit card (automatic) [False  True]
# PaymentMethod_Electronic check [ True False]
# PaymentMethod_Mailed check [False  True]
# Contract_Month-to-month [ True False]
# Contract_One year [False  True]
# Contract_Two year [False  True]
# InternetService_DSL [ True False]
# InternetService_Fiber optic [False  True]
# InternetService_No [False  True]

# %%
d1.PaperlessBilling.replace({'Yes':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/2531123738.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.PaperlessBilling.replace({'Yes':1},inplace=True)

# %%
d1.MultipleLines.replace({'No phone service':0,'No':0,'Yes':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/3290867150.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.MultipleLines.replace({'No phone service':0,'No':0,'Yes':1},inplace=True)
# /tmp/ipykernel_70993/3290867150.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.MultipleLines.replace({'No phone service':0,'No':0,'Yes':1},inplace=True)

# %%
d1.OnlineSecurity.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/3547734650.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.OnlineSecurity.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/3547734650.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.OnlineSecurity.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)

# %%
d1.OnlineBackup.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/1782444061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.OnlineBackup.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/1782444061.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.OnlineBackup.replace({'No':0,'Yes':1,'No internet service':0},inplace=True)

# %%
d1.PaperlessBilling.replace({'YEs':1,'No':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/353328274.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.PaperlessBilling.replace({'YEs':1,'No':0},inplace=True)

# %%
d1.StreamingMovies.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/2761027707.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.StreamingMovies.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/2761027707.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.StreamingMovies.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)

# %%
d1.StreamingTV.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/3260025072.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.StreamingTV.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/3260025072.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.StreamingTV.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)

# %%
d1.TechSupport.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/2964921418.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.TechSupport.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/2964921418.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.TechSupport.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)

# %%
d1.DeviceProtection.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# Out:
# /tmp/ipykernel_70993/1858524927.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.DeviceProtection.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)
# /tmp/ipykernel_70993/1858524927.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.DeviceProtection.replace({'Yes':1,'No':0,'No internet service':0},inplace=True)

# %%
d1.Dependents.replace({'Yes':0,'No':1},inplace=True)
# Out:
# /tmp/ipykernel_70993/1842747361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d1.Dependents.replace({'Yes':0,'No':1},inplace=True)
# /tmp/ipykernel_70993/1842747361.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d1.Dependents.replace({'Yes':0,'No':1},inplace=True)

# %%
d1.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# PaymentMethod_Bank transfer (automatic)       bool
# PaymentMethod_Credit card (automatic)         bool
# PaymentMethod_Electronic check                bool
# PaymentMethod_Mailed check                    bool
# Contract_Month-to-month                       bool
# Contract_One year                             bool
# Contract_Two year                             bool
# InternetService_DSL                           bool
# InternetService_Fiber optic                   bool
# InternetService_No                            bool
# dtype: object

# %%
max(d1.MonthlyCharges),max(d1.TotalCharges)
# Out:
# (118.75, 8684.8)

# %%
d1.MonthlyCharges=d1.MonthlyCharges/118.75

# %%
d1.TotalCharges=d1.TotalCharges/8684.8

# %%
d1.corr()         #knothing can be found by looking at the coorelation
# Out:
#                                            gender  SeniorCitizen   Partner  \
# gender                                   1.000000      -0.001874 -0.001808
# SeniorCitizen                           -0.001874       1.000000  0.016479
# Partner                                 -0.001808       0.016479  1.000000
# Dependents                              -0.010517       0.211185 -0.452676
# tenure                                   0.005106       0.016567  0.379697
# PhoneService                            -0.006488       0.008576  0.017706
# MultipleLines                           -0.008414       0.142948  0.142057
# OnlineSecurity                          -0.017021      -0.038653  0.143106
# OnlineBackup                            -0.013773       0.066572  0.141498
# DeviceProtection                        -0.002105       0.059428  0.153786
# TechSupport                             -0.009212      -0.060625  0.119999
# StreamingTV                             -0.008393       0.105378  0.124666
# StreamingMovies                         -0.010487       0.120176  0.117412
# PaperlessBilling                        -0.011754       0.156530 -0.014877
# MonthlyCharges                          -0.014569       0.220173  0.096848
# TotalCharges                            -0.000608       0.101917  0.319336
# Churn                                    0.008612      -0.150889  0.150448
# PaymentMethod_Bank transfer (automatic) -0.016024      -0.016159  0.110706
# PaymentMethod_Credit card (automatic)    0.001215      -0.024135  0.082029
# PaymentMethod_Electronic check           0.000752       0.171718 -0.083852
# PaymentMethod_Mailed check               0.013744      -0.153477 -0.095125
# Contract_Month-to-month                 -0.003386       0.138360 -0.280865
# Contract_One year                        0.008026      -0.046262  0.082783
# Contract_Two year                       -0.003695      -0.117000  0.248091
# InternetService_DSL                      0.006568      -0.108322 -0.000851
# InternetService_Fiber optic             -0.011286       0.255338  0.000304
# InternetService_No                       0.006026      -0.182742  0.000615
#
#                                          Dependents    tenure  PhoneService  \
# gender                                    -0.010517  0.005106     -0.006488
# SeniorCitizen                              0.211185  0.016567      0.008576
# Partner                                   -0.452676  0.379697      0.017706
# Dependents                                 1.000000 -0.159712      0.001762
# tenure                                    -0.159712  1.000000      0.008448
# PhoneService                               0.001762  0.008448      1.000000
# MultipleLines                              0.024526  0.331941      0.279690
# OnlineSecurity                            -0.080972  0.327203     -0.092893
# OnlineBackup                              -0.023671  0.360277     -0.052312
# DeviceProtection                          -0.013963  0.360653     -0.071227
# TechSupport                               -0.063268  0.324221     -0.096340
# StreamingTV                                0.016558  0.279756     -0.022574
# StreamingMovies                            0.039741  0.286111     -0.032959
# PaperlessBilling                           0.111377  0.006152      0.016505
# MonthlyCharges                             0.113890  0.247900      0.247398
# TotalCharges                              -0.065723  0.822745      0.111137
# Churn                                     -0.164221  0.352229     -0.011942
# PaymentMethod_Bank transfer (automatic)   -0.052021  0.243510      0.007556
# PaymentMethod_Credit card (automatic)     -0.060267  0.233006     -0.007721
# PaymentMethod_Electronic check             0.150642 -0.208363      0.003062
# PaymentMethod_Mailed check                -0.059071 -0.233852     -0.003319
# Contract_Month-to-month                    0.231720 -0.645561     -0.000742
# Contract_One year                         -0.068368  0.202570     -0.002791
# Contract_Two year                         -0.204613  0.558533      0.003519
# InternetService_DSL                       -0.052010  0.013274     -0.452425
# InternetService_Fiber optic                0.165818  0.019720      0.289999
# InternetService_No                        -0.139812 -0.039062      0.172209
#
#                                          MultipleLines  OnlineSecurity  \
# gender                                       -0.008414       -0.017021
# SeniorCitizen                                 0.142948       -0.038653
# Partner                                       0.142057        0.143106
# Dependents                                    0.024526       -0.080972
# tenure                                        0.331941        0.327203
# PhoneService                                  0.279690       -0.092893
# MultipleLines                                 1.000000        0.098108
# OnlineSecurity                                0.098108        1.000000
# OnlineBackup                                  0.202237        0.283832
# DeviceProtection                              0.201137        0.275438
# TechSupport                                   0.100571        0.354931
# StreamingTV                                   0.257152        0.176207
# StreamingMovies                               0.258751        0.187398
# PaperlessBilling                              0.163530       -0.003636
# MonthlyCharges                                0.490434        0.296594
# TotalCharges                                  0.467945        0.412412
# Churn                                        -0.040102        0.171226
# PaymentMethod_Bank transfer (automatic)       0.075527        0.095158
# PaymentMethod_Credit card (automatic)         0.060048        0.115721
# PaymentMethod_Electronic check                0.083618       -0.112338
# PaymentMethod_Mailed check                   -0.227206       -0.080798
# Contract_Month-to-month                      -0.088203       -0.246679
# Contract_One year                            -0.003794        0.100162
# Contract_Two year                             0.106253        0.191773
# InternetService_DSL                          -0.199920        0.321269
# InternetService_Fiber optic                   0.366083       -0.030696
# InternetService_No                           -0.210564       -0.333403
#
#                                          OnlineBackup  DeviceProtection  ...  \
# gender                                      -0.013773         -0.002105  ...
# SeniorCitizen                                0.066572          0.059428  ...
# Partner                                      0.141498          0.153786  ...
# Dependents                                  -0.023671         -0.013963  ...
# tenure                                       0.360277          0.360653  ...
# PhoneService                                -0.052312         -0.071227  ...
# MultipleLines                                0.202237          0.201137  ...
# OnlineSecurity                               0.283832          0.275438  ...
# OnlineBackup                                 1.000000          0.303546  ...
# DeviceProtection                             0.303546          1.000000  ...
# TechSupport                                  0.294233          0.333313  ...
# StreamingTV                                  0.282106          0.390874  ...
# StreamingMovies                              0.274501          0.402111  ...
# PaperlessBilling                             0.126735          0.103797  ...
# MonthlyCharges                               0.441780          0.482692  ...
# TotalCharges                                 0.509269          0.522342  ...
# Churn                                        0.082255          0.066160  ...
# PaymentMethod_Bank transfer (automatic)      0.087004          0.083115  ...
# PaymentMethod_Credit card (automatic)        0.090785          0.111554  ...
# PaymentMethod_Electronic check              -0.000408         -0.003351  ...
# PaymentMethod_Mailed check                  -0.174164         -0.187373  ...
# Contract_Month-to-month                     -0.164172         -0.225662  ...
# Contract_One year                            0.083722          0.102495  ...
# Contract_Two year                            0.111400          0.165096  ...
# InternetService_DSL                          0.157884          0.146291  ...
# InternetService_Fiber optic                  0.165651          0.176049  ...
# InternetService_No                          -0.381593         -0.380754  ...
#
#                                          PaymentMethod_Bank transfer (automatic)  \
# gender                                                                 -0.016024
# SeniorCitizen                                                          -0.016159
# Partner                                                                 0.110706
# Dependents                                                             -0.052021
# tenure                                                                  0.243510
# PhoneService                                                            0.007556
# MultipleLines                                                           0.075527
# OnlineSecurity                                                          0.095158
# OnlineBackup                                                            0.087004
# DeviceProtection                                                        0.083115
# TechSupport                                                             0.101252
# StreamingTV                                                             0.046252
# StreamingMovies                                                         0.048652
# PaperlessBilling                                                       -0.016332
# MonthlyCharges                                                          0.042812
# TotalCharges                                                            0.186171
# Churn                                                                   0.117937
# PaymentMethod_Bank transfer (automatic)                                 1.000000
# PaymentMethod_Credit card (automatic)                                  -0.278215
# PaymentMethod_Electronic check                                         -0.376762
# PaymentMethod_Mailed check                                             -0.288685
# Contract_Month-to-month                                                -0.179707
# Contract_One year                                                       0.057451
# Contract_Two year                                                       0.154471
# InternetService_DSL                                                     0.025476
# InternetService_Fiber optic                                            -0.022624
# InternetService_No                                                     -0.002113
#
#                                          PaymentMethod_Credit card (automatic)  \
# gender                                                                0.001215
# SeniorCitizen                                                        -0.024135
# Partner                                                               0.082029
# Dependents                                                           -0.060267
# tenure                                                                0.233006
# PhoneService                                                         -0.007721
# MultipleLines                                                         0.060048
# OnlineSecurity                                                        0.115721
# OnlineBackup                                                          0.090785
# DeviceProtection                                                      0.111554
# TechSupport                                                           0.117272
# StreamingTV                                                           0.040433
# StreamingMovies                                                       0.048575
# PaperlessBilling                                                     -0.013589
# MonthlyCharges                                                        0.030550
# TotalCharges                                                          0.182681
# Churn                                                                 0.134302
# PaymentMethod_Bank transfer (automatic)                              -0.278215
# PaymentMethod_Credit card (automatic)                                 1.000000
# PaymentMethod_Electronic check                                       -0.373322
# PaymentMethod_Mailed check                                           -0.286049
# Contract_Month-to-month                                              -0.204145
# Contract_One year                                                     0.067589
# Contract_Two year                                                     0.173265
# InternetService_DSL                                                   0.051438
# InternetService_Fiber optic                                          -0.050077
# InternetService_No                                                    0.001030
#
#                                          PaymentMethod_Electronic check  \
# gender                                                         0.000752
# SeniorCitizen                                                  0.171718
# Partner                                                       -0.083852
# Dependents                                                     0.150642
# tenure                                                        -0.208363
# PhoneService                                                   0.003062
# MultipleLines                                                  0.083618
# OnlineSecurity                                                -0.112338
# OnlineBackup                                                  -0.000408
# DeviceProtection                                              -0.003351
# TechSupport                                                   -0.114839
# StreamingTV                                                    0.144626
# StreamingMovies                                                0.137966
# PaperlessBilling                                               0.208865
# MonthlyCharges                                                 0.271625
# TotalCharges                                                  -0.060931
# Churn                                                         -0.301919
# PaymentMethod_Bank transfer (automatic)                       -0.376762
# PaymentMethod_Credit card (automatic)                         -0.373322
# PaymentMethod_Electronic check                                 1.000000
# PaymentMethod_Mailed check                                    -0.387372
# Contract_Month-to-month                                        0.331661
# Contract_One year                                             -0.109130
# Contract_Two year                                             -0.282138
# InternetService_DSL                                           -0.104418
# InternetService_Fiber optic                                    0.336410
# InternetService_No                                            -0.284917
#
#                                          PaymentMethod_Mailed check  \
# gender                                                     0.013744
# SeniorCitizen                                             -0.153477
# Partner                                                   -0.095125
# Dependents                                                -0.059071
# tenure                                                    -0.233852
# PhoneService                                              -0.003319
# MultipleLines                                             -0.227206
# OnlineSecurity                                            -0.080798
# OnlineBackup                                              -0.174164
# DeviceProtection                                          -0.187373
# TechSupport                                               -0.085509
# StreamingTV                                               -0.247742
# StreamingMovies                                           -0.250595
# PaperlessBilling                                          -0.205398
# MonthlyCharges                                            -0.377437
# TotalCharges                                              -0.293817
# Churn                                                      0.091683
# PaymentMethod_Bank transfer (automatic)                   -0.288685
# PaymentMethod_Credit card (automatic)                     -0.286049
# PaymentMethod_Electronic check                            -0.387372
# PaymentMethod_Mailed check                                 1.000000
# Contract_Month-to-month                                    0.004138
# Contract_One year                                         -0.000116
# Contract_Two year                                         -0.004705
# InternetService_DSL                                        0.041899
# InternetService_Fiber optic                               -0.306834
# InternetService_No                                         0.321361
#
#                                          Contract_Month-to-month  \
# gender                                                 -0.003386
# SeniorCitizen                                           0.138360
# Partner                                                -0.280865
# Dependents                                              0.231720
# tenure                                                 -0.645561
# PhoneService                                           -0.000742
# MultipleLines                                          -0.088203
# OnlineSecurity                                         -0.246679
# OnlineBackup                                           -0.164172
# DeviceProtection                                       -0.225662
# TechSupport                                            -0.285241
# StreamingTV                                            -0.112282
# StreamingMovies                                        -0.116633
# PaperlessBilling                                        0.169096
# MonthlyCharges                                          0.060165
# TotalCharges                                           -0.446759
# Churn                                                  -0.405103
# PaymentMethod_Bank transfer (automatic)                -0.179707
# PaymentMethod_Credit card (automatic)                  -0.204145
# PaymentMethod_Electronic check                          0.331661
# PaymentMethod_Mailed check                              0.004138
# Contract_Month-to-month                                 1.000000
# Contract_One year                                      -0.568744
# Contract_Two year                                      -0.622633
# InternetService_DSL                                    -0.065509
# InternetService_Fiber optic                             0.244164
# InternetService_No                                     -0.218639
#
#                                          Contract_One year  Contract_Two year  \
# gender                                            0.008026          -0.003695
# SeniorCitizen                                    -0.046262          -0.117000
# Partner                                           0.082783           0.248091
# Dependents                                       -0.068368          -0.204613
# tenure                                            0.202570           0.558533
# PhoneService                                     -0.002791           0.003519
# MultipleLines                                    -0.003794           0.106253
# OnlineSecurity                                    0.100162           0.191773
# OnlineBackup                                      0.083722           0.111400
# DeviceProtection                                  0.102495           0.165096
# TechSupport                                       0.095775           0.240824
# StreamingTV                                       0.061612           0.072049
# StreamingMovies                                   0.064926           0.073960
# PaperlessBilling                                 -0.051391          -0.147889
# MonthlyCharges                                    0.004904          -0.074681
# TotalCharges                                      0.169566           0.358582
# Churn                                             0.177820           0.302253
# PaymentMethod_Bank transfer (automatic)           0.057451           0.154471
# PaymentMethod_Credit card (automatic)             0.067589           0.173265
# PaymentMethod_Electronic check                   -0.109130          -0.282138
# PaymentMethod_Mailed check                       -0.000116          -0.004705
# Contract_Month-to-month                          -0.568744          -0.622633
# Contract_One year                                 1.000000          -0.289510
# Contract_Two year                                -0.289510           1.000000
# InternetService_DSL                               0.046795           0.031714
# InternetService_Fiber optic                      -0.076324          -0.211526
# InternetService_No                                0.038004           0.218278
#
#                                          InternetService_DSL  \
# gender                                              0.006568
# SeniorCitizen                                      -0.108322
# Partner                                            -0.000851
# Dependents                                         -0.052010
# tenure                                              0.013274
# PhoneService                                       -0.452425
# MultipleLines                                      -0.199920
# OnlineSecurity                                      0.321269
# OnlineBackup                                        0.157884
# DeviceProtection                                    0.146291
# TechSupport                                         0.313118
# StreamingTV                                         0.016274
# StreamingMovies                                     0.025698
# PaperlessBilling                                   -0.063121
# MonthlyCharges                                     -0.160189
# TotalCharges                                       -0.051416
# Churn                                               0.124214
# PaymentMethod_Bank transfer (automatic)             0.025476
# PaymentMethod_Credit card (automatic)               0.051438
# PaymentMethod_Electronic check                     -0.104418
# PaymentMethod_Mailed check                          0.041899
# Contract_Month-to-month                            -0.065509
# Contract_One year                                   0.046795
# Contract_Two year                                   0.031714
# InternetService_DSL                                 1.000000
# InternetService_Fiber optic                        -0.640987
# InternetService_No                                 -0.380635
#
#                                          InternetService_Fiber optic  \
# gender                                                     -0.011286
# SeniorCitizen                                               0.255338
# Partner                                                     0.000304
# Dependents                                                  0.165818
# tenure                                                      0.019720
# PhoneService                                                0.289999
# MultipleLines                                               0.366083
# OnlineSecurity                                             -0.030696
# OnlineBackup                                                0.165651
# DeviceProtection                                            0.176049
# TechSupport                                                -0.020492
# StreamingTV                                                 0.329349
# StreamingMovies                                             0.322923
# PaperlessBilling                                            0.326853
# MonthlyCharges                                              0.787066
# TotalCharges                                                0.359413
# Churn                                                      -0.308020
# PaymentMethod_Bank transfer (automatic)                    -0.022624
# PaymentMethod_Credit card (automatic)                      -0.050077
# PaymentMethod_Electronic check                              0.336410
# PaymentMethod_Mailed check                                 -0.306834
# Contract_Month-to-month                                     0.244164
# Contract_One year                                          -0.076324
# Contract_Two year                                          -0.211526
# InternetService_DSL                                        -0.640987
# InternetService_Fiber optic                                 1.000000
# InternetService_No                                         -0.465793
#
#                                          InternetService_No
# gender                                             0.006026
# SeniorCitizen                                     -0.182742
# Partner                                            0.000615
# Dependents                                        -0.139812
# tenure                                            -0.039062
# PhoneService                                       0.172209
# MultipleLines                                     -0.210564
# OnlineSecurity                                    -0.333403
# OnlineBackup                                      -0.381593
# DeviceProtection                                  -0.380754
# TechSupport                                       -0.336298
# StreamingTV                                       -0.415552
# StreamingMovies                                   -0.418675
# PaperlessBilling                                  -0.321013
# MonthlyCharges                                    -0.763557
# TotalCharges                                      -0.373734
# Churn                                              0.227890
# PaymentMethod_Bank transfer (automatic)           -0.002113
# PaymentMethod_Credit card (automatic)              0.001030
# PaymentMethod_Electronic check                    -0.284917
# PaymentMethod_Mailed check                         0.321361
# Contract_Month-to-month                           -0.218639
# Contract_One year                                  0.038004
# Contract_Two year                                  0.218278
# InternetService_DSL                               -0.380635
# InternetService_Fiber optic                       -0.465793
# InternetService_No                                 1.000000
#
# [27 rows x 27 columns]

# %%
d1.corr()         #knothing can be found by looking at the coorelation
# Out:
#                                            gender  SeniorCitizen   Partner  \
# gender                                   1.000000      -0.001874 -0.001808
# SeniorCitizen                           -0.001874       1.000000  0.016479
# Partner                                 -0.001808       0.016479  1.000000
# Dependents                              -0.010517       0.211185 -0.452676
# tenure                                   0.005106       0.016567  0.379697
# PhoneService                            -0.006488       0.008576  0.017706
# MultipleLines                           -0.008414       0.142948  0.142057
# OnlineSecurity                          -0.017021      -0.038653  0.143106
# OnlineBackup                            -0.013773       0.066572  0.141498
# DeviceProtection                        -0.002105       0.059428  0.153786
# TechSupport                             -0.009212      -0.060625  0.119999
# StreamingTV                             -0.008393       0.105378  0.124666
# StreamingMovies                         -0.010487       0.120176  0.117412
# PaperlessBilling                        -0.011754       0.156530 -0.014877
# MonthlyCharges                          -0.014569       0.220173  0.096848
# TotalCharges                            -0.000608       0.101917  0.319336
# Churn                                    0.008612      -0.150889  0.150448
# PaymentMethod_Bank transfer (automatic) -0.016024      -0.016159  0.110706
# PaymentMethod_Credit card (automatic)    0.001215      -0.024135  0.082029
# PaymentMethod_Electronic check           0.000752       0.171718 -0.083852
# PaymentMethod_Mailed check               0.013744      -0.153477 -0.095125
# Contract_Month-to-month                 -0.003386       0.138360 -0.280865
# Contract_One year                        0.008026      -0.046262  0.082783
# Contract_Two year                       -0.003695      -0.117000  0.248091
# InternetService_DSL                      0.006568      -0.108322 -0.000851
# InternetService_Fiber optic             -0.011286       0.255338  0.000304
# InternetService_No                       0.006026      -0.182742  0.000615
#
#                                          Dependents    tenure  PhoneService  \
# gender                                    -0.010517  0.005106     -0.006488
# SeniorCitizen                              0.211185  0.016567      0.008576
# Partner                                   -0.452676  0.379697      0.017706
# Dependents                                 1.000000 -0.159712      0.001762
# tenure                                    -0.159712  1.000000      0.008448
# PhoneService                               0.001762  0.008448      1.000000
# MultipleLines                              0.024526  0.331941      0.279690
# OnlineSecurity                            -0.080972  0.327203     -0.092893
# OnlineBackup                              -0.023671  0.360277     -0.052312
# DeviceProtection                          -0.013963  0.360653     -0.071227
# TechSupport                               -0.063268  0.324221     -0.096340
# StreamingTV                                0.016558  0.279756     -0.022574
# StreamingMovies                            0.039741  0.286111     -0.032959
# PaperlessBilling                           0.111377  0.006152      0.016505
# MonthlyCharges                             0.113890  0.247900      0.247398
# TotalCharges                              -0.065723  0.822745      0.111137
# Churn                                     -0.164221  0.352229     -0.011942
# PaymentMethod_Bank transfer (automatic)   -0.052021  0.243510      0.007556
# PaymentMethod_Credit card (automatic)     -0.060267  0.233006     -0.007721
# PaymentMethod_Electronic check             0.150642 -0.208363      0.003062
# PaymentMethod_Mailed check                -0.059071 -0.233852     -0.003319
# Contract_Month-to-month                    0.231720 -0.645561     -0.000742
# Contract_One year                         -0.068368  0.202570     -0.002791
# Contract_Two year                         -0.204613  0.558533      0.003519
# InternetService_DSL                       -0.052010  0.013274     -0.452425
# InternetService_Fiber optic                0.165818  0.019720      0.289999
# InternetService_No                        -0.139812 -0.039062      0.172209
#
#                                          MultipleLines  OnlineSecurity  \
# gender                                       -0.008414       -0.017021
# SeniorCitizen                                 0.142948       -0.038653
# Partner                                       0.142057        0.143106
# Dependents                                    0.024526       -0.080972
# tenure                                        0.331941        0.327203
# PhoneService                                  0.279690       -0.092893
# MultipleLines                                 1.000000        0.098108
# OnlineSecurity                                0.098108        1.000000
# OnlineBackup                                  0.202237        0.283832
# DeviceProtection                              0.201137        0.275438
# TechSupport                                   0.100571        0.354931
# StreamingTV                                   0.257152        0.176207
# StreamingMovies                               0.258751        0.187398
# PaperlessBilling                              0.163530       -0.003636
# MonthlyCharges                                0.490434        0.296594
# TotalCharges                                  0.467945        0.412412
# Churn                                        -0.040102        0.171226
# PaymentMethod_Bank transfer (automatic)       0.075527        0.095158
# PaymentMethod_Credit card (automatic)         0.060048        0.115721
# PaymentMethod_Electronic check                0.083618       -0.112338
# PaymentMethod_Mailed check                   -0.227206       -0.080798
# Contract_Month-to-month                      -0.088203       -0.246679
# Contract_One year                            -0.003794        0.100162
# Contract_Two year                             0.106253        0.191773
# InternetService_DSL                          -0.199920        0.321269
# InternetService_Fiber optic                   0.366083       -0.030696
# InternetService_No                           -0.210564       -0.333403
#
#                                          OnlineBackup  DeviceProtection  ...  \
# gender                                      -0.013773         -0.002105  ...
# SeniorCitizen                                0.066572          0.059428  ...
# Partner                                      0.141498          0.153786  ...
# Dependents                                  -0.023671         -0.013963  ...
# tenure                                       0.360277          0.360653  ...
# PhoneService                                -0.052312         -0.071227  ...
# MultipleLines                                0.202237          0.201137  ...
# OnlineSecurity                               0.283832          0.275438  ...
# OnlineBackup                                 1.000000          0.303546  ...
# DeviceProtection                             0.303546          1.000000  ...
# TechSupport                                  0.294233          0.333313  ...
# StreamingTV                                  0.282106          0.390874  ...
# StreamingMovies                              0.274501          0.402111  ...
# PaperlessBilling                             0.126735          0.103797  ...
# MonthlyCharges                               0.441780          0.482692  ...
# TotalCharges                                 0.509269          0.522342  ...
# Churn                                        0.082255          0.066160  ...
# PaymentMethod_Bank transfer (automatic)      0.087004          0.083115  ...
# PaymentMethod_Credit card (automatic)        0.090785          0.111554  ...
# PaymentMethod_Electronic check              -0.000408         -0.003351  ...
# PaymentMethod_Mailed check                  -0.174164         -0.187373  ...
# Contract_Month-to-month                     -0.164172         -0.225662  ...
# Contract_One year                            0.083722          0.102495  ...
# Contract_Two year                            0.111400          0.165096  ...
# InternetService_DSL                          0.157884          0.146291  ...
# InternetService_Fiber optic                  0.165651          0.176049  ...
# InternetService_No                          -0.381593         -0.380754  ...
#
#                                          PaymentMethod_Bank transfer (automatic)  \
# gender                                                                 -0.016024
# SeniorCitizen                                                          -0.016159
# Partner                                                                 0.110706
# Dependents                                                             -0.052021
# tenure                                                                  0.243510
# PhoneService                                                            0.007556
# MultipleLines                                                           0.075527
# OnlineSecurity                                                          0.095158
# OnlineBackup                                                            0.087004
# DeviceProtection                                                        0.083115
# TechSupport                                                             0.101252
# StreamingTV                                                             0.046252
# StreamingMovies                                                         0.048652
# PaperlessBilling                                                       -0.016332
# MonthlyCharges                                                          0.042812
# TotalCharges                                                            0.186171
# Churn                                                                   0.117937
# PaymentMethod_Bank transfer (automatic)                                 1.000000
# PaymentMethod_Credit card (automatic)                                  -0.278215
# PaymentMethod_Electronic check                                         -0.376762
# PaymentMethod_Mailed check                                             -0.288685
# Contract_Month-to-month                                                -0.179707
# Contract_One year                                                       0.057451
# Contract_Two year                                                       0.154471
# InternetService_DSL                                                     0.025476
# InternetService_Fiber optic                                            -0.022624
# InternetService_No                                                     -0.002113
#
#                                          PaymentMethod_Credit card (automatic)  \
# gender                                                                0.001215
# SeniorCitizen                                                        -0.024135
# Partner                                                               0.082029
# Dependents                                                           -0.060267
# tenure                                                                0.233006
# PhoneService                                                         -0.007721
# MultipleLines                                                         0.060048
# OnlineSecurity                                                        0.115721
# OnlineBackup                                                          0.090785
# DeviceProtection                                                      0.111554
# TechSupport                                                           0.117272
# StreamingTV                                                           0.040433
# StreamingMovies                                                       0.048575
# PaperlessBilling                                                     -0.013589
# MonthlyCharges                                                        0.030550
# TotalCharges                                                          0.182681
# Churn                                                                 0.134302
# PaymentMethod_Bank transfer (automatic)                              -0.278215
# PaymentMethod_Credit card (automatic)                                 1.000000
# PaymentMethod_Electronic check                                       -0.373322
# PaymentMethod_Mailed check                                           -0.286049
# Contract_Month-to-month                                              -0.204145
# Contract_One year                                                     0.067589
# Contract_Two year                                                     0.173265
# InternetService_DSL                                                   0.051438
# InternetService_Fiber optic                                          -0.050077
# InternetService_No                                                    0.001030
#
#                                          PaymentMethod_Electronic check  \
# gender                                                         0.000752
# SeniorCitizen                                                  0.171718
# Partner                                                       -0.083852
# Dependents                                                     0.150642
# tenure                                                        -0.208363
# PhoneService                                                   0.003062
# MultipleLines                                                  0.083618
# OnlineSecurity                                                -0.112338
# OnlineBackup                                                  -0.000408
# DeviceProtection                                              -0.003351
# TechSupport                                                   -0.114839
# StreamingTV                                                    0.144626
# StreamingMovies                                                0.137966
# PaperlessBilling                                               0.208865
# MonthlyCharges                                                 0.271625
# TotalCharges                                                  -0.060931
# Churn                                                         -0.301919
# PaymentMethod_Bank transfer (automatic)                       -0.376762
# PaymentMethod_Credit card (automatic)                         -0.373322
# PaymentMethod_Electronic check                                 1.000000
# PaymentMethod_Mailed check                                    -0.387372
# Contract_Month-to-month                                        0.331661
# Contract_One year                                             -0.109130
# Contract_Two year                                             -0.282138
# InternetService_DSL                                           -0.104418
# InternetService_Fiber optic                                    0.336410
# InternetService_No                                            -0.284917
#
#                                          PaymentMethod_Mailed check  \
# gender                                                     0.013744
# SeniorCitizen                                             -0.153477
# Partner                                                   -0.095125
# Dependents                                                -0.059071
# tenure                                                    -0.233852
# PhoneService                                              -0.003319
# MultipleLines                                             -0.227206
# OnlineSecurity                                            -0.080798
# OnlineBackup                                              -0.174164
# DeviceProtection                                          -0.187373
# TechSupport                                               -0.085509
# StreamingTV                                               -0.247742
# StreamingMovies                                           -0.250595
# PaperlessBilling                                          -0.205398
# MonthlyCharges                                            -0.377437
# TotalCharges                                              -0.293817
# Churn                                                      0.091683
# PaymentMethod_Bank transfer (automatic)                   -0.288685
# PaymentMethod_Credit card (automatic)                     -0.286049
# PaymentMethod_Electronic check                            -0.387372
# PaymentMethod_Mailed check                                 1.000000
# Contract_Month-to-month                                    0.004138
# Contract_One year                                         -0.000116
# Contract_Two year                                         -0.004705
# InternetService_DSL                                        0.041899
# InternetService_Fiber optic                               -0.306834
# InternetService_No                                         0.321361
#
#                                          Contract_Month-to-month  \
# gender                                                 -0.003386
# SeniorCitizen                                           0.138360
# Partner                                                -0.280865
# Dependents                                              0.231720
# tenure                                                 -0.645561
# PhoneService                                           -0.000742
# MultipleLines                                          -0.088203
# OnlineSecurity                                         -0.246679
# OnlineBackup                                           -0.164172
# DeviceProtection                                       -0.225662
# TechSupport                                            -0.285241
# StreamingTV                                            -0.112282
# StreamingMovies                                        -0.116633
# PaperlessBilling                                        0.169096
# MonthlyCharges                                          0.060165
# TotalCharges                                           -0.446759
# Churn                                                  -0.405103
# PaymentMethod_Bank transfer (automatic)                -0.179707
# PaymentMethod_Credit card (automatic)                  -0.204145
# PaymentMethod_Electronic check                          0.331661
# PaymentMethod_Mailed check                              0.004138
# Contract_Month-to-month                                 1.000000
# Contract_One year                                      -0.568744
# Contract_Two year                                      -0.622633
# InternetService_DSL                                    -0.065509
# InternetService_Fiber optic                             0.244164
# InternetService_No                                     -0.218639
#
#                                          Contract_One year  Contract_Two year  \
# gender                                            0.008026          -0.003695
# SeniorCitizen                                    -0.046262          -0.117000
# Partner                                           0.082783           0.248091
# Dependents                                       -0.068368          -0.204613
# tenure                                            0.202570           0.558533
# PhoneService                                     -0.002791           0.003519
# MultipleLines                                    -0.003794           0.106253
# OnlineSecurity                                    0.100162           0.191773
# OnlineBackup                                      0.083722           0.111400
# DeviceProtection                                  0.102495           0.165096
# TechSupport                                       0.095775           0.240824
# StreamingTV                                       0.061612           0.072049
# StreamingMovies                                   0.064926           0.073960
# PaperlessBilling                                 -0.051391          -0.147889
# MonthlyCharges                                    0.004904          -0.074681
# TotalCharges                                      0.169566           0.358582
# Churn                                             0.177820           0.302253
# PaymentMethod_Bank transfer (automatic)           0.057451           0.154471
# PaymentMethod_Credit card (automatic)             0.067589           0.173265
# PaymentMethod_Electronic check                   -0.109130          -0.282138
# PaymentMethod_Mailed check                       -0.000116          -0.004705
# Contract_Month-to-month                          -0.568744          -0.622633
# Contract_One year                                 1.000000          -0.289510
# Contract_Two year                                -0.289510           1.000000
# InternetService_DSL                               0.046795           0.031714
# InternetService_Fiber optic                      -0.076324          -0.211526
# InternetService_No                                0.038004           0.218278
#
#                                          InternetService_DSL  \
# gender                                              0.006568
# SeniorCitizen                                      -0.108322
# Partner                                            -0.000851
# Dependents                                         -0.052010
# tenure                                              0.013274
# PhoneService                                       -0.452425
# MultipleLines                                      -0.199920
# OnlineSecurity                                      0.321269
# OnlineBackup                                        0.157884
# DeviceProtection                                    0.146291
# TechSupport                                         0.313118
# StreamingTV                                         0.016274
# StreamingMovies                                     0.025698
# PaperlessBilling                                   -0.063121
# MonthlyCharges                                     -0.160189
# TotalCharges                                       -0.051416
# Churn                                               0.124214
# PaymentMethod_Bank transfer (automatic)             0.025476
# PaymentMethod_Credit card (automatic)               0.051438
# PaymentMethod_Electronic check                     -0.104418
# PaymentMethod_Mailed check                          0.041899
# Contract_Month-to-month                            -0.065509
# Contract_One year                                   0.046795
# Contract_Two year                                   0.031714
# InternetService_DSL                                 1.000000
# InternetService_Fiber optic                        -0.640987
# InternetService_No                                 -0.380635
#
#                                          InternetService_Fiber optic  \
# gender                                                     -0.011286
# SeniorCitizen                                               0.255338
# Partner                                                     0.000304
# Dependents                                                  0.165818
# tenure                                                      0.019720
# PhoneService                                                0.289999
# MultipleLines                                               0.366083
# OnlineSecurity                                             -0.030696
# OnlineBackup                                                0.165651
# DeviceProtection                                            0.176049
# TechSupport                                                -0.020492
# StreamingTV                                                 0.329349
# StreamingMovies                                             0.322923
# PaperlessBilling                                            0.326853
# MonthlyCharges                                              0.787066
# TotalCharges                                                0.359413
# Churn                                                      -0.308020
# PaymentMethod_Bank transfer (automatic)                    -0.022624
# PaymentMethod_Credit card (automatic)                      -0.050077
# PaymentMethod_Electronic check                              0.336410
# PaymentMethod_Mailed check                                 -0.306834
# Contract_Month-to-month                                     0.244164
# Contract_One year                                          -0.076324
# Contract_Two year                                          -0.211526
# InternetService_DSL                                        -0.640987
# InternetService_Fiber optic                                 1.000000
# InternetService_No                                         -0.465793
#
#                                          InternetService_No
# gender                                             0.006026
# SeniorCitizen                                     -0.182742
# Partner                                            0.000615
# Dependents                                        -0.139812
# tenure                                            -0.039062
# PhoneService                                       0.172209
# MultipleLines                                     -0.210564
# OnlineSecurity                                    -0.333403
# OnlineBackup                                      -0.381593
# DeviceProtection                                  -0.380754
# TechSupport                                       -0.336298
# StreamingTV                                       -0.415552
# StreamingMovies                                   -0.418675
# PaperlessBilling                                  -0.321013
# MonthlyCharges                                    -0.763557
# TotalCharges                                      -0.373734
# Churn                                              0.227890
# PaymentMethod_Bank transfer (automatic)           -0.002113
# PaymentMethod_Credit card (automatic)              0.001030
# PaymentMethod_Electronic check                    -0.284917
# PaymentMethod_Mailed check                         0.321361
# Contract_Month-to-month                           -0.218639
# Contract_One year                                  0.038004
# Contract_Two year                                  0.218278
# InternetService_DSL                               -0.380635
# InternetService_Fiber optic                       -0.465793
# InternetService_No                                 1.000000
#
# [27 rows x 27 columns]

# %%
d1.shape,27/5
# Out:
# ((7043, 27), 5.4)

# %%
from tensorflow import keras

# %%
model=keras.Sequential([keras.layers.Dense(20,input_shape=(26,),activation='relu'),
                        keras.layers.Dense(13,activation='relu'),
                        keras.layers.Dense(1,activation='sigmoid')])
# Out:
# /home/magendra/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='BinaryCrossentropy',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split as t

# %%
xtr,xte,ytr,yte=t(d1.iloc[:,:-1],d1.iloc[:,-1])

# %%
xtr.shape,ytr.shape
# Out:
# ((5282, 26), (5282,))

# %%
from sklearn.linear_model import LogisticRegression as l

# %%
l1=l()

# %%
l1.fit(xtr,ytr)
# Out:
# LogisticRegression()

# %%
l1.predict(xte)
# Out:
# array([ True,  True, False, ...,  True, False,  True])

# %%
l1.predict_proba(xte)
# Out:
# array([[1.30607789e-02, 9.86939221e-01],
#        [3.30796954e-02, 9.66920305e-01],
#        [9.97264018e-01, 2.73598188e-03],
#        ...,
#        [2.81716483e-02, 9.71828352e-01],
#        [9.99384189e-01, 6.15810539e-04],
#        [3.92894022e-03, 9.96071060e-01]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay as c

# %%
from sklearn.metrics import confusion_matrix as cc

# %%
cc(yte,l1.predict(xte))
# Out:
# array([[1391,    0],
#        [   0,  370]])

# %%
c(confusion_matrix=cc(yte,l1.predict(xte))).plot()

# %%
c.plot
# Out:
# <function sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay.plot(self, *, include_values=True, cmap='viridis', xticks_rotation='horizontal', values_format=None, ax=None, colorbar=True, im_kw=None, text_kw=None)>

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %% [markdown]
# #
